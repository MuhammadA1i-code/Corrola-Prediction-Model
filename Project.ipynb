# %%
# Import required libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout


file_path = '/mnt/data/ProjectTrainingDataFinalFINALCONFIRM.xlsx'
data = pd.ExcelFile('/content/drive/MyDrive/ProjectTrainingDataFinalFINALCONFIRM.xlsx')
df = data.parse(data.sheet_names[0])

def clean_data(df):

    df.columns = df.columns.str.lower().str.replace(' ', '_')


    if 'se/le' in df.columns:
        df['se/le'] = df['se/le'].str.upper().map({'YES': 1, 'NO': 0}).fillna(0)


    columns_to_drop = ['year_of_upload']
    cleaned_data = df.drop(columns=[col for col in columns_to_drop if col in df.columns])

    return cleaned_data


cleaned_data = clean_data(df)

#Define categorical and numerical features
categorical_features = ['car_name', 'fuel_type', 'transmission']
numerical_features = ['model_year', 'se/le']

# One-hot encode categorical features
encoder = OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore')
encoded_features = encoder.fit_transform(cleaned_data[categorical_features])

# Combine encoded features with numerical features
X = pd.DataFrame(encoded_features, columns=encoder.get_feature_names_out(categorical_features))
X = pd.concat([cleaned_data[numerical_features].reset_index(drop=True), X], axis=1)
y = cleaned_data['car_price']

# Standardize numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Build the TensorFlow model
model = Sequential([
    Dense(128, input_dim=X_train.shape[1], activation='relu'),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dense(1)  # Output layer for regression
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# Train the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=32, verbose=1)

# Evaluate the model
loss, mae = model.evaluate(X_test, y_test, verbose=0)
print(f"Mean Absolute Error: {mae:.2f}")

# Implement Gradient Boosting for comparison
gbr = GradientBoostingRegressor(n_estimators=200, learning_rate=0.1, max_depth=5, random_state=42)
gbr.fit(X_train, y_train)
gbr_predictions = gbr.predict(X_test)
gbr_mae = mean_absolute_error(y_test, gbr_predictions)
print(f"Gradient Boosting Regressor MAE: {gbr_mae:.2f}")

# Cross-validation for robustness
kf = KFold(n_splits=5, shuffle=True, random_state=42)
cross_val_errors = []
for train_index, val_index in kf.split(X_scaled):
    X_train_cv, X_val_cv = X_scaled[train_index], X_scaled[val_index]
    y_train_cv, y_val_cv = y[train_index], y[val_index]

    model.fit(X_train_cv, y_train_cv, epochs=50, batch_size=32, verbose=0)
    val_loss, val_mae = model.evaluate(X_val_cv, y_val_cv, verbose=0)
    cross_val_errors.append(val_mae)

print(f"Cross-validated MAE: {np.mean(cross_val_errors):.2f}")

# Function to predict custom configurations
def predict_specific_price(car_name, model_year, fuel_type, transmission, se_le, predicted_year):
    # Prepare the input data
    custom_data = pd.DataFrame({
        'car_name': [car_name],
        'model_year': [model_year],
        'fuel_type': [fuel_type],
        'transmission': [transmission],
        'se/le': [se_le]
    })

    # Encode and standardize the input data
    custom_encoded = encoder.transform(custom_data[categorical_features])
    custom_data_transformed = pd.DataFrame(custom_encoded, columns=encoder.get_feature_names_out(categorical_features))
    custom_data_transformed = pd.concat([custom_data[['model_year', 'se/le']].reset_index(drop=True), custom_data_transformed], axis=1)
    custom_data_scaled = scaler.transform(custom_data_transformed)

    # Predict the price
    predicted_price = model.predict(custom_data_scaled).flatten()[0]
    return predicted_price, predicted_year

# Example inflation rate function
def get_inflation_rate(year):
    # Define a dictionary or function with historical/forecasted inflation rates
    inflation_rates = {
        2023: 0.03,  # Example rates: 3% inflation for 2023
        2024: 0.025,
        2025: 0.02,
    }
    # Default to the last known rate if the year is not in the dictionary
    return inflation_rates.get(year, inflation_rates[max(inflation_rates)])

# Adjust the predict_specific_price function to include inflation
def predict_specific_price(car_name, model_year, fuel_type, transmission, se_le, predicted_year):
    # Prepare the input data
    custom_data = pd.DataFrame({
        'car_name': [car_name],
        'model_year': [model_year],
        'fuel_type': [fuel_type],
        'transmission': [transmission],
        'se/le': [se_le]
    })

    # Encode and standardize the input data
    custom_encoded = encoder.transform(custom_data[categorical_features])
    custom_data_transformed = pd.DataFrame(custom_encoded, columns=encoder.get_feature_names_out(categorical_features))
    custom_data_transformed = pd.concat([custom_data[['model_year', 'se/le']].reset_index(drop=True), custom_data_transformed], axis=1)
    custom_data_scaled = scaler.transform(custom_data_transformed)

    # Predict the price for the current year
    predicted_price = model.predict(custom_data_scaled).flatten()[0]

    # Adjust for inflation to the predicted year
    current_year = 2023  # Set to the current year of prediction
    adjusted_price = predicted_price
    for year in range(current_year + 1, predicted_year + 1):
        adjusted_price *= (1 + get_inflation_rate(year))

    return adjusted_price, predicted_year

# Example usage: Predict price for a specific car with inflation adjustment
car_name = input("Car name: ")
model_year = int(input("Model year: "))
fuel_type = input("Fuel type: ")
transmission = input("Car transmission: ")
se_le = int(input("Is the car a SE/LE (1 for Yes, 0 for No): "))
predicted_year = int(input("Which year do you want to predict: "))

predicted_price, year = predict_specific_price(car_name, model_year, fuel_type, transmission, se_le, predicted_year)
print(f"\nPredicted price for {car_name} (Model Year: {model_year}) in {year}: {predicted_price:.2f}")
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 647.4113 - mean_absolute_error: 22.8002 - val_loss: 622.2076 - val_mean_absolute_error: 21.9174
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 527.2830 - mean_absolute_error: 20.2038 - val_loss: 451.3147 - val_mean_absolute_error: 17.8410
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 372.0497 - mean_absolute_error: 16.1496 - val_loss: 197.1050 - val_mean_absolute_error: 10.1706
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 149.9955 - mean_absolute_error: 9.1134 - val_loss: 86.0286 - val_mean_absolute_error: 6.8153
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 98.2421 - mean_absolute_error: 7.0348 - val_loss: 66.7188 - val_mean_absolute_error: 5.8774
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 67.3180 - mean_absolute_error: 5.5343 - val_loss: 62.0191 - val_mean_absolute_error: 5.2659
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 54.6369 - mean_absolute_error: 5.0277 - val_loss: 52.8922 - val_mean_absolute_error: 5.0698
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 38.2774 - mean_absolute_error: 4.4807 - val_loss: 50.6974 - val_mean_absolute_error: 4.9072
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 50.5928 - mean_absolute_error: 5.1625 - val_loss: 46.9563 - val_mean_absolute_error: 4.9236
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 45.6038 - mean_absolute_error: 5.0563 - val_loss: 46.2240 - val_mean_absolute_error: 4.7056
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 47.7501 - mean_absolute_error: 5.1111 - val_loss: 44.0916 - val_mean_absolute_error: 4.8016
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.6393 - mean_absolute_error: 4.7571 - val_loss: 44.8583 - val_mean_absolute_error: 4.6113
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 54.1384 - mean_absolute_error: 5.1451 - val_loss: 43.2075 - val_mean_absolute_error: 4.5488
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 41.4460 - mean_absolute_error: 4.4252 - val_loss: 42.1952 - val_mean_absolute_error: 4.5389
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.6243 - mean_absolute_error: 4.7138 - val_loss: 41.3775 - val_mean_absolute_error: 4.4278
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.7854 - mean_absolute_error: 4.9455 - val_loss: 40.6708 - val_mean_absolute_error: 4.5056
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 41.5859 - mean_absolute_error: 4.6898 - val_loss: 42.4510 - val_mean_absolute_error: 4.4435
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 39.2238 - mean_absolute_error: 4.2916 - val_loss: 39.9412 - val_mean_absolute_error: 4.4862
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 50.2119 - mean_absolute_error: 5.0623 - val_loss: 39.9926 - val_mean_absolute_error: 4.3353
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 37.5768 - mean_absolute_error: 4.4107 - val_loss: 39.6488 - val_mean_absolute_error: 4.3273
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 43.3350 - mean_absolute_error: 4.6915 - val_loss: 38.1503 - val_mean_absolute_error: 4.4798
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.4783 - mean_absolute_error: 4.6530 - val_loss: 40.3433 - val_mean_absolute_error: 4.3121
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 37.6287 - mean_absolute_error: 4.4708 - val_loss: 38.9187 - val_mean_absolute_error: 4.3902
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 42.1870 - mean_absolute_error: 4.6403 - val_loss: 39.1274 - val_mean_absolute_error: 4.3991
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 41.1027 - mean_absolute_error: 4.4399 - val_loss: 38.7600 - val_mean_absolute_error: 4.3448
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 39.5750 - mean_absolute_error: 4.6600 - val_loss: 37.9384 - val_mean_absolute_error: 4.4613
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 37.7492 - mean_absolute_error: 4.3554 - val_loss: 38.8482 - val_mean_absolute_error: 4.3634
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 42.2320 - mean_absolute_error: 4.7000 - val_loss: 38.2033 - val_mean_absolute_error: 4.2907
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 40.1935 - mean_absolute_error: 4.4977 - val_loss: 39.7299 - val_mean_absolute_error: 4.2113
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 35.9943 - mean_absolute_error: 4.2656 - val_loss: 36.9803 - val_mean_absolute_error: 4.3046
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.1917 - mean_absolute_error: 4.2457 - val_loss: 38.1436 - val_mean_absolute_error: 4.0761
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 34.3929 - mean_absolute_error: 4.2649 - val_loss: 38.2433 - val_mean_absolute_error: 4.1835
# Epoch 33/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 34.5939 - mean_absolute_error: 4.3479 - val_loss: 37.9067 - val_mean_absolute_error: 4.2263
# Epoch 34/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 38.9805 - mean_absolute_error: 4.5590 - val_loss: 40.1567 - val_mean_absolute_error: 4.1490
# Epoch 35/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32.9358 - mean_absolute_error: 4.1473 - val_loss: 37.9958 - val_mean_absolute_error: 4.1378
# Epoch 36/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 39.3473 - mean_absolute_error: 4.6181 - val_loss: 38.5170 - val_mean_absolute_error: 4.1631
# Epoch 37/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 36.2315 - mean_absolute_error: 4.2475 - val_loss: 37.8805 - val_mean_absolute_error: 4.1822
# Epoch 38/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 39.4542 - mean_absolute_error: 4.5125 - val_loss: 38.6833 - val_mean_absolute_error: 4.2552
# Epoch 39/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 35.9379 - mean_absolute_error: 4.3423 - val_loss: 38.8881 - val_mean_absolute_error: 4.2822
# Epoch 40/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 39.1350 - mean_absolute_error: 4.3773 - val_loss: 40.5020 - val_mean_absolute_error: 4.2042
# Epoch 41/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 48.8621 - mean_absolute_error: 4.4364 - val_loss: 36.9889 - val_mean_absolute_error: 4.2074
# Epoch 42/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 36.4977 - mean_absolute_error: 4.5389 - val_loss: 38.5407 - val_mean_absolute_error: 4.1878
# Epoch 43/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 44.1421 - mean_absolute_error: 4.9794 - val_loss: 38.3102 - val_mean_absolute_error: 4.2530
# Epoch 44/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 34.2070 - mean_absolute_error: 4.1979 - val_loss: 38.7626 - val_mean_absolute_error: 4.2286
# Epoch 45/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 37.6518 - mean_absolute_error: 4.3658 - val_loss: 37.7418 - val_mean_absolute_error: 4.3478
# Epoch 46/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 35.1883 - mean_absolute_error: 4.3740 - val_loss: 39.2336 - val_mean_absolute_error: 4.1418
# Epoch 47/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 36.4571 - mean_absolute_error: 4.4517 - val_loss: 38.4718 - val_mean_absolute_error: 4.2231
# Epoch 48/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 41.4368 - mean_absolute_error: 4.6501 - val_loss: 38.6002 - val_mean_absolute_error: 4.1871
# Epoch 49/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 36.5000 - mean_absolute_error: 4.2475 - val_loss: 40.3165 - val_mean_absolute_error: 4.1391
# Epoch 50/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 34.7817 - mean_absolute_error: 4.1745 - val_loss: 37.8474 - val_mean_absolute_error: 4.1433
# Epoch 51/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34.9630 - mean_absolute_error: 4.3367 - val_loss: 39.4589 - val_mean_absolute_error: 4.1144
# Epoch 52/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 34.0625 - mean_absolute_error: 4.1526 - val_loss: 39.2675 - val_mean_absolute_error: 4.2168
# Epoch 53/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 32.2403 - mean_absolute_error: 4.2298 - val_loss: 39.3328 - val_mean_absolute_error: 4.1863
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 38.0174 - mean_absolute_error: 4.3003 - val_loss: 39.1225 - val_mean_absolute_error: 4.1871
# Epoch 55/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 34.2263 - mean_absolute_error: 4.2194 - val_loss: 38.9325 - val_mean_absolute_error: 4.1815
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 38.6775 - mean_absolute_error: 4.4891 - val_loss: 40.2181 - val_mean_absolute_error: 4.0687
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 40.3607 - mean_absolute_error: 4.6296 - val_loss: 38.2337 - val_mean_absolute_error: 4.1097
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 35.9835 - mean_absolute_error: 4.3182 - val_loss: 38.9998 - val_mean_absolute_error: 3.9479
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 35.7069 - mean_absolute_error: 4.1698 - val_loss: 38.4585 - val_mean_absolute_error: 3.9911
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 29.7286 - mean_absolute_error: 4.0215 - val_loss: 40.3027 - val_mean_absolute_error: 3.9685
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 37.1639 - mean_absolute_error: 4.2197 - val_loss: 38.5847 - val_mean_absolute_error: 3.9975
# Epoch 62/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 35.9714 - mean_absolute_error: 4.1752 - val_loss: 38.8361 - val_mean_absolute_error: 3.9817
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 40.5036 - mean_absolute_error: 4.3617 - val_loss: 38.6430 - val_mean_absolute_error: 3.9920
# Epoch 64/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 40.3388 - mean_absolute_error: 4.4734 - val_loss: 38.6594 - val_mean_absolute_error: 4.0009
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 29.0659 - mean_absolute_error: 3.9699 - val_loss: 38.7436 - val_mean_absolute_error: 4.0933
# Epoch 66/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 34.2850 - mean_absolute_error: 4.3464 - val_loss: 40.2076 - val_mean_absolute_error: 4.0545
# Epoch 67/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.2672 - mean_absolute_error: 3.9669 - val_loss: 39.5587 - val_mean_absolute_error: 4.1245
# Epoch 68/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 43.2573 - mean_absolute_error: 4.6999 - val_loss: 40.3094 - val_mean_absolute_error: 4.0839
# Epoch 69/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 35.2149 - mean_absolute_error: 4.1429 - val_loss: 39.5210 - val_mean_absolute_error: 4.0915
# Epoch 70/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 25.3195 - mean_absolute_error: 3.6599 - val_loss: 39.9586 - val_mean_absolute_error: 4.0711
# Epoch 71/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.2093 - mean_absolute_error: 4.1086 - val_loss: 39.3684 - val_mean_absolute_error: 4.1045
# Epoch 72/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 33.1441 - mean_absolute_error: 4.0369 - val_loss: 39.8532 - val_mean_absolute_error: 4.1114
# Epoch 73/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 30.8603 - mean_absolute_error: 4.0382 - val_loss: 39.5964 - val_mean_absolute_error: 4.1796
# Epoch 74/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 40.6457 - mean_absolute_error: 4.6403 - val_loss: 41.5839 - val_mean_absolute_error: 4.1724
# Epoch 75/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.2540 - mean_absolute_error: 3.9572 - val_loss: 39.8298 - val_mean_absolute_error: 4.1472
# Epoch 76/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 37.0432 - mean_absolute_error: 4.3726 - val_loss: 40.9320 - val_mean_absolute_error: 4.1508
# Epoch 77/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 40.8862 - mean_absolute_error: 4.5773 - val_loss: 41.7271 - val_mean_absolute_error: 4.0386
# Epoch 78/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 46.5740 - mean_absolute_error: 4.8338 - val_loss: 41.2705 - val_mean_absolute_error: 4.0777
# Epoch 79/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34.7479 - mean_absolute_error: 4.0834 - val_loss: 40.8914 - val_mean_absolute_error: 4.1742
# Epoch 80/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 42.8471 - mean_absolute_error: 4.6051 - val_loss: 41.5539 - val_mean_absolute_error: 4.1512
# Epoch 81/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.8801 - mean_absolute_error: 4.0376 - val_loss: 41.6448 - val_mean_absolute_error: 4.1548
# Epoch 82/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.1045 - mean_absolute_error: 4.0304 - val_loss: 41.9234 - val_mean_absolute_error: 4.1146
# Epoch 83/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34.9251 - mean_absolute_error: 4.4012 - val_loss: 41.3420 - val_mean_absolute_error: 4.1334
# Epoch 84/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 36.5810 - mean_absolute_error: 4.2954 - val_loss: 41.7414 - val_mean_absolute_error: 4.0896
# Epoch 85/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 34.7186 - mean_absolute_error: 4.1480 - val_loss: 40.5475 - val_mean_absolute_error: 4.0992
# Epoch 86/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32.9550 - mean_absolute_error: 4.1903 - val_loss: 41.8738 - val_mean_absolute_error: 4.1182
# Epoch 87/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.7763 - mean_absolute_error: 4.4439 - val_loss: 40.6924 - val_mean_absolute_error: 4.1552
# Epoch 88/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 35.9805 - mean_absolute_error: 4.3847 - val_loss: 41.2787 - val_mean_absolute_error: 4.0441
# Epoch 89/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.9264 - mean_absolute_error: 4.0320 - val_loss: 40.5543 - val_mean_absolute_error: 4.1273
# Epoch 90/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.5476 - mean_absolute_error: 3.8570 - val_loss: 41.2739 - val_mean_absolute_error: 4.0509
# Epoch 91/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32.9923 - mean_absolute_error: 4.1570 - val_loss: 41.1749 - val_mean_absolute_error: 4.0624
# Epoch 92/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 42.3946 - mean_absolute_error: 4.5365 - val_loss: 45.0478 - val_mean_absolute_error: 4.0300
# Epoch 93/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 35.7362 - mean_absolute_error: 4.1485 - val_loss: 41.4482 - val_mean_absolute_error: 4.2736
# Epoch 94/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34.4041 - mean_absolute_error: 4.3394 - val_loss: 44.2305 - val_mean_absolute_error: 4.1378
# Epoch 95/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 34.0949 - mean_absolute_error: 4.0510 - val_loss: 40.6723 - val_mean_absolute_error: 4.4020
# Epoch 96/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 36.7553 - mean_absolute_error: 4.5023 - val_loss: 44.2209 - val_mean_absolute_error: 4.1185
# Epoch 97/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32.9869 - mean_absolute_error: 4.0160 - val_loss: 41.7334 - val_mean_absolute_error: 4.1577
# Epoch 98/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.5673 - mean_absolute_error: 3.9113 - val_loss: 43.9376 - val_mean_absolute_error: 4.1606
# Epoch 99/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 37.1525 - mean_absolute_error: 4.3216 - val_loss: 44.2886 - val_mean_absolute_error: 4.2975
# Epoch 100/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.1566 - mean_absolute_error: 3.7514 - val_loss: 44.4818 - val_mean_absolute_error: 4.1470
# Mean Absolute Error: 4.15
# Gradient Boosting Regressor MAE: 4.20
# Cross-validated MAE: 3.64
# Car name: Toyota Corolla 2.0D
# Model year: 2004
# Fuel type: Diesel
# Car transmission: Manual
# Is the car a SE/LE (1 for Yes, 0 for No): 0
# Which year do you want to predict: 2024
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0, 1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x79f97cb609d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#
# Predicted price for Toyota Corolla 2.0D (Model Year: 2004) in 2024: 11.06
